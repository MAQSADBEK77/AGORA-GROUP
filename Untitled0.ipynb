# %% [markdown]
# <a href="https://colab.research.google.com/github/MAQSADBEK77/AGORA-GROUP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import torchvision
import torch
import torch.nn as nn
import torch.optim as optim

# Создаём структуру папок
# !mkdir -p data/train/cancer data/train/normal data/val/cancer data/val/normal

print("✅ Папки успешно созданы!")
print("Теперь перетащи свои фото в эти папки слева в разделе Files")
# Out:
# ✅ Папки успешно созданы!
# Теперь перетащи свои фото в эти папки слева в разделе Files

# %%
# ==================== ПОДГОТОВКА ДАННЫХ ====================
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

train_dataset = datasets.ImageFolder("data/train", transform=transform)
val_dataset = datasets.ImageFolder("data/val", transform=transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

print("Классы:", train_dataset.classes)

# ==================== МОДЕЛЬ ====================
model = torchvision.models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 2)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# ==================== ОБУЧЕНИЕ ====================
print("Начинаем обучение...")

for epoch in range(5):   # Можно увеличить до 10-15 позже
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Эпоха {epoch+1}/5 | Loss: {running_loss/len(train_loader):.4f}")

# Сохранение модели
torch.save(model.state_dict(), "/content/model_breast.pth")
print("✅ Обучение завершено! Модель сохранена как model_breast.pth")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_12729/3258306362.py in <cell line: 0>()
#       6 ])
#       7
# ----> 8 train_dataset = datasets.ImageFolder("data/train", transform=transform)
#       9 val_dataset = datasets.ImageFolder("data/val", transform=transform)
#      10
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
# ...

# %%
# Установка библиотеки kaggle
# !pip install -q kaggle

# Создаём папку
import os
os.makedirs('/root/.kaggle', exist_ok=True)

print("Готово! Теперь нужно загрузить kaggle.json")
# Out:
# Готово! Теперь нужно загрузить kaggle.json

# %%
from google.colab import files
files.upload()   # ← Загрузи сюда свой файл kaggle.json
# Out:
#      <input type="file" id="files-041286aa-8dcc-4698-a8a8-660e484bff79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-041286aa-8dcc-4698-a8a8-660e484bff79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
